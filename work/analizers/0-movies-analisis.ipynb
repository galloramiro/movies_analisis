# %% [markdown]
# # Project Overview

# %%
from services.factories import ServicesFactorie

static_movies_analyze_service = ServicesFactorie().get_static_movies_analyse_service()
interactive_movies_analyze_service = ServicesFactorie().get_interactive_movies_analyse_service()

# %% [markdown]
# # Question

# %% [markdown]
# ### What is the relationshinp between the revenue and the budget?

# %%
#static_movies_analyze_service.get_revenue_vs_budget_analisis()
# interactive_movies_analyze_service.get_revenue_vs_budget_analisis()

# %% [markdown]
# ### What is the relationshinp between the popularity and the budget?

# %%
# static_movies_analyze_service.get_popularity_vs_budget_analisis()
# interactive_movies_analyze_service.get_popularity_vs_budget_analisis()

# %% [markdown]
# ### What is the relationshinp between the revenue and votes average?

# %%
# static_movies_analyze_service.get_reveneu_vs_votes_average_analisis()
# interactive_movies_analyze_service.get_reveneu_vs_votes_average_analisis()

# %% [markdown]
# ### What is the relationshinp between the popularity and votes average?

# %%
# static_movies_analyze_service.get_popularity_vs_votes_average_analisis()
# interactive_movies_analyze_service.get_popularity_vs_votes_average_analisis()

# %% [markdown]
# ### What is the relationshinp between the budget and votes average?

# %%
# static_movies_analyze_service.get_budget_vs_votes_average_analisis()
# interactive_movies_analyze_service.get_budget_vs_votes_average_analisis()
