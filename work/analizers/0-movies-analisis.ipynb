# %% [markdown]
# ### Question
# - Has the popularity have a relationship with the budget?
#   get_popularity_vs_budget_by_year_df
# - Has the revenue have a relationship with the budget?
#   get_revenue_vs_budget_by_year_df
# - What is the relation between revenew and votes?
#   get_revenew_vs_votes_average
# - What is the relation between popularity and votes?
#   get_popularity_vs_votes_average
# - What is the relation between budget and votes?
#   get_budget_vs_votes_average

# %%
from services.movies.files_handlers import MoviesCsvHandler
from services.movies.ploter import StaticPlots

csv_handler = MoviesCsvHandler()
static_plots = StaticPlots()

# %%
revenue_vs_budget_df = csv_handler.get_revenue_vs_budget_by_year_df(last_few_years=2)
# revenue_vs_budget_df.head()
# static_plots.plot_reveneu_vs_budget(revenue_vs_budget_df)

# %%
popularity_vs_budget_df = csv_handler.get_popularity_vs_budget_by_year_df(last_few_years=2)
# popularity_vs_budget_df.head()
# static_plots.plot_popularity_vs_budget(popularity_vs_budget_df)

# %%
revenew_vs_votes_avg = csv_handler.get_revenew_vs_votes_average(last_few_years=2)
# revenew_vs_votes_avg.head()
# static_plots.plot_revenew_vs_votes_average(revenew_vs_votes_avg)

# %%
popularity_vs_votes_avg = csv_handler.get_popularity_vs_votes_average(last_few_years=2)
# popularity_vs_votes_avg.head()
# static_plots.plot_popularity_vs_votes_average(popularity_vs_votes_avg)

# %%
budget_vs_votes_avg = csv_handler.get_budget_vs_votes_average(last_few_years=2)
# budget_vs_votes_avg.head()
# static_plots.plot_budget_vs_votes_average(budget_vs_votes_avg)
